# %%
import os
os.chdir("..")

import pandas as pd

# %%
from src.obtain.raw_data import get_iris

# %%
df = get_iris()
# Out:
# Loading from backup

# %%
df.columns = \
map(lambda i: ''.join([x for x in i.lower() if x not in './()& ']).replace('cm', ''),
   df.columns)

# %%
df.to_csv("data/processed/iris.csv", encoding='utf-8', index=False)
